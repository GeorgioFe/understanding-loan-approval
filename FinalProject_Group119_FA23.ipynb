# %% [markdown]
# # COGS 108 - Final Project
#
# # Understanding Loan Approval: A Data Analysis
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [`X`] NO - keep private
#
#
# # Video
# Link to our Presentation video: https://drive.google.com/file/d/1yjAx54PVbWzhUV1HcgCsUbGjW8J8stgP/view?usp=drive_link
#
#
# # Names
#
# - Joseph Lee
# - Kenneth Song
# - Georgio Feghali
# - Lorenzo Ramos
# - Sujay Talanki
#
# # Abstract
#
# This project aims to analyze the relationship between an applicant’s credit background and loan approval status. In particular, we want to analyze certain aspects of credit background, such as an applicant’s income, credit history, employment status, etc. number of dependents, graduate status, loan amount, property area and see how they relate to loan status approval. We gathered the data online via Kaggle. Afterwards, we cleaned and wrangled the dataset to prepare it for analysis. Through EDA, we constructed many visuals examining interaction betweens the variables and the target variable (loan status approval). Through our analyses, we concluded that there are certain factors that could be related to an applicant’s loan approval status. These variables are: applicant’s income, credit history, employment status, number of dependents, graduate status, loan amount, and property area. Through machine learning techniques, we can quantify how well these factors can predict an applicant’s loan approval status! After tuning a RandomForestClassifier, we were able to achieve 83% classification accuracy! This indicates that these variables could be important when deciding an applicant’s loan approval. Looking at the feature importance for each variable, it seems like loan amount, employment status, education, and number of dependents are the most important features when determining loan status approval. It is important to note that our dataset has a relatively small sample size, and little is known about the integrity of this dataset. Thus, it is difficult to claim with certainty that these variables are the most important when predicting loan approval, but our results show that they at least somewhat contribute to an applicant’s chances at loan approval.

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there a relationship between an applicant’s credit history (whether or not an applicant's credit history meets the bank's guidelines), income, loan amount, employment status, property area, dependents and their loan approval status in America?
#
# We would like to see if these variables (and potentially more) in aggregate have a strong indicator of an applicant's loan approval status

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# <!-- Banks that give out loans need to make sure that they will get a return on their investment (they need to make sure that the borrower will be able to repay the money with the interest). Thus, it would be trivial to think that certain aspects of an applicant's credit history could play a factor when banks are deciding on when to give loans. Could we tune a machine learning model to accurately predict whether or not an applicant will receive a loan? This is the topic we are interested in!
#
# There have been a few projects that have explored the issue using various machine learning algorithms. “How to predict Loan Eligibility using Machine Learning Models”$^{[1](https://towardsdatascience.com/predict-loan-eligibility-using-machine-learning-models-7a14ef904057#:~:text=Applicants%20who%20have%20repaid%20their,the%20chances%20of%20loan%20approval)}$ uses a few different machine learning models to predict loan eligibility using some background information. This topic is different from ours, as our dataset will be different and the features are different. “Loan Prediction Problem from Scratch to End”$^{2}$ uses logistic regression, decision tree, and random forest classifiers to predict loan eligibility from certain features of an applicant. It is the same dataset as linked above, but uses different metrics and methods to build their model. Our models will be different because we will use in-depth hyperparameter tuning or potentially neural networks to build our model. These are topics likely not discussed in class, but we would like to explore them if possible.
#
# “How does my Credit Score Affect my Loan Chances?”$^{3}$ talks about the potential features that could affect an applicant's chances at a loan approval. They talk about how FICO score, income, employment status, debt, and other attributes of an applicant's financial status could affect the chances at loan approval.
#
# 1. ^ https://towardsdatascience.com/predict-loan-eligibility-using-machine-learning-models-7a14ef904057#:~:text=Applicants%20who%20have%20repaid%20their,the%20chances%20of%20loan%20approval.
# “How to predict Loan Eligibility using Machine Learning Models”
#
# 2. ^ https://www.analyticsvidhya.com/blog/2022/05/loan-prediction-problem-from-scratch-to-end/
# “How to predict Loan Eligibility using Machine Learning Models”
#
# 3. ^ https://www.bankrate.com/loans/personal-loans/how-does-credit-score-affect-loan-chances/
# “How does my Credit Score Affect my Loan Chances?” -->
#
# Banks that give out loans need to make sure that they will get a return on their investment (they need to make sure that the borrower will be able to repay the money with the interest). Thus, it would be trivial to think that certain aspects of an applicant's credit history could play a factor when banks are deciding on when to give loans. Could we tune a machine learning model to accurately predict whether or not an applicant will receive a loan? This is the topic we are interested in!
#
#
# There have been a few projects that have explored the issue using various machine learning algorithms. “How to predict Loan Eligibility using Machine Learning Models”<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) uses a few different machine learning models to predict loan eligibility using some background information. This topic is different from ours, as our dataset will be different and the features are different. “Loan Prediction Problem from Scratch to End”<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) uses logistic regression, decision tree, and random forest classifiers to predict loan eligibility from certain features of an applicant. It is the same dataset as linked above, but uses different metrics and methods to build their model. Our models will be different because we will use in-depth hyperparameter tuning or potentially neural networks to build our model. These are topics likely not discussed in class, but we would like to explore them if possible.
#
# “How does my Credit Score Affect my Loan Chances?”<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-2) talks about the potential features that could affect an applicant's chances at a loan approval. They talk about how FICO score, income, employment status, debt, and other attributes of an applicant's financial status could affect the chances at loan approval.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) https://towardsdatascience.com/predict-loan-eligibility-using-machine-learning-models-7a14ef904057#:~:text=Applicants%20who%20have%20repaid%20their,the%20chances%20of%20loan%20approval.
#
# “How to predict Loan Eligibility using Machine Learning Models”
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) https://www.analyticsvidhya.com/blog/2022/05/loan-prediction-problem-from-scratch-to-end/
#
# “How to predict Loan Eligibility using Machine Learning Models”
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) https://www.bankrate.com/loans/personal-loans/how-does-credit-score-affect-loan-chances/
#
# “How does my Credit Score Affect my Loan Chances?”

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that employment status, loan amount, education, income, credit history, and property area collectively influence the likelihood of loan approval. Our hypothesis is rooted in the understanding that certain applicant characteristics, such as a positive credit history meeting the bank's guidelines, higher income, and potentially other socio-demographic factors, contribute significantly to the favorable outcome of loan approval. We expect that applicants with a strong credit history, higher income, and potentially certain demographic attributes, such as being a graduate or residing in specific property areas, are more likely to have their loan applications approved.
#
# To address potential confounding factors and broaden our analysis, we will consider variables such as debt-to-income ratio, employment status and stability, collateral, and loan-to-value ratio. These additional variables aim to capture the complexity of financial situations and loan applications, providing a more comprehensive understanding of the relationship between credit history, income, loan term amount, and loan approval status. We believe that a thorough examination of these factors will enrich our insights and contribute to a nuanced understanding of the dynamics influencing loan approval decisions.

# %% [markdown]
# # Data

# %% [markdown]
# The ideal dataset that we would want in order to answer our question would be one that revolves around loan approvals.
# The main variables that we are looking for are:
#
# * Income (int/float)
# * Loan Amount (int/float)
# * Loan Term and Interest Rates (int)
# * Loan Approval (bool)
# * Credit History (bool)
# * Loan Type (string)
#
# Some other variables that aren’t necessarily needed but could be helpful are:
#
# * Gender (str)
# * Age (int)
# * Marital Status (bool)
# * Number of dependents (int)
# * Cosigner(s) (bool)
#
# Observations: the more the better (but at least 300) Data Collection
#
# * Lenders
# * Financial Institutions
# * Credit Bureaus
# * Government Agencies
#
# Data Storage
#
# * Data will be stored in a dataset? (.csv preferably)
# * Each row represents applicant or loan
# * Anonymized for data privacy (more on ethics)
# * Organized in such a way that allows ease of retrieval, filtering and analysis
# * Could use relational database

# %% [markdown]
# ## Data overview
#
#   - Dataset Name: Home Loan Approval Dataset
#   - Link to the dataset: https://www.kaggle.com/datasets/rishikeshkonapure/home-loan-approval/data
#   - Number of observations: 981 (614 in train set, 367 in test set)
#   - Number of variables: 12
#
# The dataset contains information about loan applicants: age (int, measured in years), gender (string, male or female), marital status (string, married or not married), education (string, graduate or not a graduate), income details (float, income in USD), credit history (boolean/binary, whether or not the the credit history meets the bank's guidelines), property area (string, urban, sem-urban, rural), and loan approval status (boolean/binary, whether or not the loan was approved). Some of the key numerical metrics include ApplicantIncome, CoapplicantIncome, LoanAmount, and LoanAmountTerm, while CreditHistory is a binary variable representing the creditworthiness of an applicant. We plan to preprocess the data by handling missing values (dropping some null values, mean/mode imputation, and one hot encoding for categorical variables) and changing variable names to a uniform format. This is a supervised machine learning (classification) task and will use preprocessing, feature selection, cross validation, model selection, and hyperparameter tuning to develop the most accurate model.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import warnings
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, accuracy_score, classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

from scipy.stats import norm
import xgboost as xgb
import lightgbm as lgbm
pd.options.display.float_format = '{:.0f}'.format
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Home Loan Approval Dataset

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
df = pd.read_csv('data.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0         NaN               360
# 1             4583               1508         128               360
# 2             3000                  0          66               360
# 3             2583               2358         120               360
# 4             6000                  0         141               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...

# %% [markdown]
# ### Change the column names to uniform format (space in between words)

# %%
df.columns = ['Loan ID', 'Gender', 'Married', 'Dependents', 'Education',
       'Self Employed', 'Applicant Income', 'Coapplicant Income', 'Loan Amount',
       'Loan Amount Term', 'Credit History', 'Property Area', 'Loan Status']

# %% [markdown]
# ### Exploring Missingness

# %%
# Looking at the missing values per column
df.isna().sum()
# Out:
# Loan ID                0
# Gender                13
# Married                3
# Dependents            15
# Education              0
# Self Employed         32
# Applicant Income       0
# Coapplicant Income     0
# Loan Amount           22
# Loan Amount Term      14
# Credit History        50
# Property Area          0
# Loan Status            0
# dtype: int64

# %% [markdown]
# It looks like Self Employed and Credit History have the most missing values. A potential reason that Self Employed has many missing values is that those who are self-employed may not want to indicate that they are self employed, so they will leave the entry blank. Another potential reason is that the answer isn't as simple as 'Yes' or 'No', so the entry was left blank. In terms of the Credit History column, the only two possible values are 1 or 0 (if the credit history meets the requirements or not). A potential reason that these values might be empty is if the credit history has not been checked/verified to see if it meets the guidelines.

# %%
df['Credit History'].value_counts()
# Out:
# 1    475
# 0     89
# Name: Credit History, dtype: int64

# %% [markdown]
# ### Looking at the Missingness Matrix

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# After looking at the missingness matrix, it seems like the missingness of 'Dependents' and 'Married' could be connected with one another (there are lines that span both columns for multiple rows). Other than that, it seems like the other columns have no relationship with one another (in terms of missingness)

# %% [markdown]
# ### Looking at the Missingness Heatmap

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap (and our matrix interpretation above), it seems that the missingness between the Dependents and Married might be related (the value is 0.4 in the heatmap). The other variables don't seem to have relationships (with regards to missingness)

# %% [markdown]
# ### Handling Missingness

# %% [markdown]
# Since there are very few values missing for the Married column, we will just drop those. For the Self Employed and Loan Amount Term categories, there is a dominating value (the mode makes a high percentage of the values in the column), so we will just impute the mode for these two columns. For the Loan Amount column, we will just impute the mean, as this column is numeric and doesn't seem to have a dominating value. For credit history, we will just leave these as np.nan values, and see how our model does (we cannot impute the mean as it a binary variable, and we don't want to impute the mode as this variable might be a strong indicator of Loan Approval, we may consider deleting these rows later on). It seems like there is a relationship between the missingness of 'Married' and 'Dependants' columns (MAR). We don't know if we should drop these values or use Multiple Imputation (beyond the scope of this course). We will leave these as nan's for now.

# %%
# Dropping rows where the Married values are empty
df = df.dropna(subset=['Married'])
df['Self Employed'] = df['Self Employed'].fillna(df['Self Employed'].mode()[0])
df['Loan Amount Term'] = df['Loan Amount Term'].fillna(df['Loan Amount Term'].mode()[0])
df['Loan Amount'] = df['Loan Amount'].fillna(df['Loan Amount'].mean())

# %%
df.isna().sum()
# Out:
# Loan ID                0
# Gender                13
# Married                0
# Dependents            12
# Education              0
# Self Employed          0
# Applicant Income       0
# Coapplicant Income     0
# Loan Amount            0
# Loan Amount Term       0
# Credit History        50
# Property Area          0
# Loan Status            0
# dtype: int64

# %% [markdown]
# We have dealt with the missingness of multiple columns, and will handle the other missing values when we are developing our model!

# %% [markdown]
# Here is a look at our clean data!

# %%
df.sample(20)
# Out:
#       Loan ID  Gender Married Dependents     Education Self Employed  \
# 541  LP002743  Female      No          0      Graduate            No
# 482  LP002537    Male     Yes          0      Graduate            No
# 165  LP001574    Male     Yes          0      Graduate            No
# 350  LP002139    Male     Yes          0      Graduate            No
# 311  LP002004    Male      No          0  Not Graduate            No
# 64   LP001222  Female      No          0      Graduate            No
# 507  LP002625     NaN      No          0      Graduate            No
# 219  LP001734  Female     Yes          2      Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# 575  LP002868    Male     Yes          2      Graduate            No
# 192  LP001657    Male     Yes          0  Not Graduate            No
# 395  LP002272    Male     Yes          2      Graduate            No
# 292  LP001940    Male     Yes          2      Graduate            No
# ...

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### EDA Part 1: Pairwise Analysis of Quantitative Variables

# %%
df['Total Income'] = df['Applicant Income'] + df['Coapplicant Income']
dfhm = df[['Applicant Income', 'Coapplicant Income', 'Total Income', 'Loan Amount', 'Loan Amount Term']]
sns.heatmap(dfhm.corr(), annot=True)
plt.title('Correlation Heat Map')
plt.show()

# %% [markdown]
# From the heatmap (and our matrix interpretation above), it seems that there seems to be a higher relationship between the pairs of Total Income and Applicant Income (the value is 0.89 in the heatmap), Loan Amount and Total Income (the value is 0.62 in the heatmap), and Loan Amount and Applicant Income (the value is 0.57 in the heatmap). The other pairs have either no relationship (value is less than 0 in the heatmap) or little correlation to each other (value is less than 0.5 in the heatmap).

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# From the pairplots above, it seems as though there seems to be more correlation between the 3 pairs of variables described from the heatmap. When the individual dots are closer to each other (skewed left or right), that means that there is a higher correlation/relationship between the two variables. For example, there is a higher relationship between Loan Amount and Applicant Income since most of the data points are clustered into the left area of the graph. And when the dots are more scattered, that means there is a less likely chance of the points being related to each other.

# %% [markdown]
# ### EDA Part 2: Univariate Analysis of Variables

# %%
df['Loan Status'].value_counts().plot(kind = 'bar')
plt.title('Distribution of Loan Statuses')
plt.ylabel('Count')
plt.xlabel('Loan Status')
plt.show()

# %% [markdown]
# When there are more loans that are distributed, there are twice more loans that are approved than those that aren't. There are 50% less No's than Yes's for loan status. That means that this helps us lean towards our goal of answering if there is a relationship between loan approval and loan status.

# %%
df = df[['Loan ID', 'Gender', 'Married', 'Dependents', 'Education',
       'Self Employed', 'Applicant Income', 'Coapplicant Income', 'Total Income',
       'Loan Amount', 'Loan Amount Term', 'Credit History', 'Property Area',
       'Loan Status']]
df.shape
# Out:
# (611, 14)

# %%
plt.hist(df['Total Income'], bins = 15)
plt.title('Distribution of Total Income')
plt.xlabel('Income ($)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This graph shows the relationship between what an individual makes versus how many loans are distributed. It is very clear that there are more loans that are distributed for households earning less money, specifically, the households who are earning less than $10,000 a month. It makes sense that people who are making less money have more of a need to request for loans for their households. This basically means that income amount doesn't really correlate to higher loan approvals.

# %% [markdown]
# ### EDA Part 3: Bivariate Analysis

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [8, 6]
plt.rcParams["figure.autolayout"] = True

data = pd.DataFrame({"Loan Status Approved": df[df['Loan Status'] == 'Y']['Total Income'], "Loan Status Rejected": df[df['Loan Status'] == 'N']['Total Income']})
data[['Loan Status Approved', 'Loan Status Rejected']].plot(kind='box', title='boxplot')
plt.title('Distribution of Total Income by Loan Status Approval')
plt.ylabel('Total Income ($)')
plt.show()

# %% [markdown]
# In this graph, it shows the relationship between loan status and total income. The mean and medians for each box and whisker plot is around 5000 a month for each. There are a lot more outliers if the loan status is approved, meaning that there are more households that are approved for a loan. (Most of the outliers are approved rather than rejected.) If the loan is approved, then there are more households earning around 10,000 - 20,000 per month than the other households earning different incomes.

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [8, 6]
plt.rcParams["figure.autolayout"] = True

data = pd.DataFrame({"Graduate Income": df[df['Education'] == 'Graduate']['Total Income'], "Non-Graduate Income": df[df['Education'] == 'Not Graduate']['Total Income']})
data[['Graduate Income', 'Non-Graduate Income']].plot(kind='box', title='boxplot')
plt.title('Distribution of Total Income by Graduate Status')
plt.ylabel('Total Income ($)')
plt.show()

# %% [markdown]
# In this graph, it shows the relationship between graduate/non-graduate income(s) and total income(s). The mean and medians for each box and whisker plot is around $5000 a month for each. There are a lot more outliers for the graduate income, meaning that graduates are likely to have a higher income than those who didn't graduate. (Most of the outliers are in graduate income rather than non-gradate income.)

# %%
plt.subplot(1, 2, 1)
plt.ylabel('Counts')
plt.title("Distribution of Marital Status for Approved Applicants")
df[df['Loan Status'] == 'Y']['Married'].value_counts().plot(kind = 'bar')

plt.subplot(1, 2, 2)
plt.title("Distribution of Marital Status for Non-approved Applicants")
df[df['Loan Status'] == 'N']['Married'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# This graph shows that people who are married have a higher likelihood to get approved for a loan versus people who are not married and has a lower chance to get approved for a loan. This could be because people who are married are entitled to more benefits and loans might favor those who are married to show a more positive outcome from using that loan.

# %% [markdown]
# ## Model Building

# %%
df = pd.read_csv('data.csv')
df.columns = ['Loan ID', 'Gender', 'Married', 'Dependents', 'Education',
       'Self Employed', 'Applicant Income', 'Coapplicant Income', 'Loan Amount',
       'Loan Amount Term', 'Credit History', 'Property Area', 'Loan Status']
df['Total Income'] = df['Applicant Income'] + df['Coapplicant Income']

# %% [markdown]
# ### Setting up the training and test data

# %%
numeric = list(df.select_dtypes(include=['float64', 'int64']).columns)
categorical = list(df.select_dtypes(include=['object']).columns)

#Dropping variables we aren't interested in
try:
    categorical.remove('Loan ID')
    categorical.remove('Loan Status')
    categorical.remove('Gender')
    categorical.remove('Married')
    numeric.remove('Applicant Income')
    numeric.remove('Coapplicant Income')
    
except:
    ...

#Setting up the training and test data
X = df.drop(columns = ['Loan ID', 'Gender', 'Married', 'Applicant Income', 'Coapplicant Income', 'Loan Status'], axis=1)
y = df['Loan Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=201)

# %% [markdown]
# ### Functions to preprocess and model the data in an sklearn pipeline
#
# We utilized sklearn pipelines and transformers to preprocess the data (deal with missing values and employ one hot encoding), and
# compile the models into pipeline objects for fitting.

# %%
# Engineers sklearn pipeline to preprocess the data and features
def make_model(classifier):
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='median')),
        ('scale', StandardScaler())
    ])

    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('ohe', OneHotEncoder(handle_unknown='ignore'))
    ])

    preproc = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numeric),
        ('category', categorical_pipeline, categorical),
    ])

    #Setting up a pipeline
    pl = Pipeline([
        ('preprocessor', preproc),
        ('model', classifier)
        ])

    return pl

# Fits the model to the training data
def model_fit(model):
    model = make_model(model)
    model.fit(X_train, y_train)
    return model

# %% [markdown]
# ### Model Choice Explanation
#
# In modern supervised machine learning, the most frequent algorithms used are ensemble methods. Ensemble machine learning methods are techniques that combine the predictions of multiple individual models to produce a stronger and more robust predictive model. The idea behind ensembles is that the collective wisdom of multiple models can often outperform a single model, especially when individual models may have limitations or biases. We will attempt to utizilize two popular **boosting** ensemble methods:
#
# (1) LightGBM Classifier - belongs to the family of gradient boosting machines. Gradient boosting involves training a series of weak learners (usually decision trees) sequentially, with each new learner focused on correcting the errors of the previous ones. It is particularly effective on large datasets (might not be great for our small dataset...) and implements overfitting techniques on its own accord.
#
# (2) Random Forest Classifier - combines multiple decision trees to make predictions. Each decision tree is a simple model that makes decisions by asking a series of questions based on input features. It is known for its simplicity and versatility.
#
# Boosting algorithms work sequentially, with each model trained to correct the errors of its predecessor. They aim to improve the overall performance of the ensemble by focusing on the instances that are challenging to classify.

# %% [markdown]
# ### Testing base accuracy with a 5-fold CV

# %%
lgbm_base_model = model_fit(lgbm.LGBMClassifier(task='predict', boosting_type='gbdt'))
rfc_base_model = model_fit(rfc())

print("LightGBM Base Accuracy: " + str(np.mean(cross_val_score(lgbm_base_model, X, y, cv=10))))
print("Random Forest Classifier Base Accuracy: " + str(np.mean(cross_val_score(rfc_base_model, X, y, cv=10))))
# Out:
# LightGBM Base Accuracy: 0.77374405076679
# Random Forest Classifier Base Accuracy: 0.7754098360655737

# %% [markdown]
# It seems as both models achieve a 77%-78% base accuracy without any tuning, let's see if we can improve the model performance!

# %% [markdown]
# ## Hyperparameter Tuning with GridSearchCV

# %% [markdown]
# ### Tuning for LightGBM

# %%
lgbm_pl = make_model(lgbm.LGBMClassifier(task='predict', boosting_type='gbdt'))

parameterslgbm = {
                'model__num_iterations': [200, 400],
                'model__learning_rate': [0.05, 0.1, .15, .18],
                'model__num_leaves': [30, 34, 40],
                'model__n_estimators': [20, 24, 30],
                'model__feature_fraction': [0.85, 0.9, 0.95],
                'model__bagging_fraction': [0.9, 0.95, 1],
                'model__bagging_freq': [150, 180, 200, 220]
                }

lgbm_grid = GridSearchCV(lgbm_pl,
                        parameterslgbm,
                        scoring='accuracy',
                        cv = 3,
                        verbose=False,
                        n_jobs=15,
                        )

lgbm_grid.fit(X, y)

print(lgbm_grid.best_params_)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=200, subsample_freq=0 will be ignored. Current value: bagging_freq=200
# {'model__bagging_fraction': 0.9, 'model__bagging_freq': 200, 'model__feature_fraction': 0.9, 'model__learning_rate': 0.05, 'model__n_estimators': 20, 'model__num_iterations': 200, 'model__num_leaves': 30}

# %% [markdown]
# We employed GridSearchCV to find the optimal hyperparameters for the LightGBM model

# %%
model_lgbm_tuned = model_fit(lgbm.LGBMClassifier(task='predict',
                                                   boosting_type='gbdt',
                                                   bagging_fraction=.9,
                                                   bagging_freq=200,
                                                   feature_fraction=0.9,
                                                   learning_rate=0.05,
                                                   n_estimators=20,
                                                   num_iterations=200,
                                                   num_leaves=30))

lgbm_preds = model_lgbm_tuned.predict(X_test)
print(classification_report(y_test, lgbm_preds))

cm = confusion_matrix(y_test, lgbm_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            N       0.69      0.47      0.56        51
#            Y       0.77      0.89      0.83       103
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.68      0.69       154
# weighted avg       0.74      0.75      0.74       154

# %% [markdown]
# It looks as if the hyperparameter tuning did not help for the LightGBM model. LightGBM typically works the best on large datasets, and actually implements hyperparameter tuning in the building process, so our extra efforts may have been counter-productive. We will now try the RandomForestClassifier instead!

# %% [markdown]
# ### Tuning for RandomForestClassifier

# %%
rfc_pl = make_model(rfc())

parametersrfc = {
    'model__n_estimators': [100, 200, 300],  # Number of trees in the forest
    'model__max_depth': [None, 10, 20, 30, 40],  # Maximum depth of each tree
    'model__min_samples_split': [2, 4, 5],  # Minimum samples required to split a node
    'model__min_samples_leaf': [1, 2, 4],  # Minimum samples required in a leaf node
    'model__max_features': ['auto', 'sqrt', 'log'],  # Number of features to consider for the best split
    'model__bootstrap': [True],  # Whether to bootstrap samples when building trees
    'model__criterion': ['gini', 'entropy']  # Stopping rule     
}

rfc_grid = GridSearchCV(rfc_pl,
                        parametersrfc,
                        scoring='accuracy',
                        cv = 5,
                        verbose=False,
                        n_jobs=15
                        )

rfc_grid.fit(X, y)

print(rfc_grid.best_params_)
# Out:
# {'model__bootstrap': True, 'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 100}

# %% [markdown]
# These are the results after using GridSearchCV to search for the optimal hyperparameters for RFC!

# %%
model_rfc = rfc(bootstrap=True,
                                criterion='gini',
                                max_depth=10,
                                max_features='auto',
                                min_samples_leaf=2,
                                min_samples_split=2,
                                n_estimators=300)
model_rfc_tuned = model_fit(model_rfc)

rfc_preds = model_rfc_tuned.predict(X_test)
print(classification_report(y_test, rfc_preds))

cm = confusion_matrix(y_test, rfc_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            N       0.92      0.45      0.61        51
#            Y       0.78      0.98      0.87       103
#
#     accuracy                           0.81       154
#    macro avg       0.85      0.72      0.74       154
# weighted avg       0.83      0.81      0.78       154

# %% [markdown]
# As you can see, it looks like the RandomForestClassifier works the best, because the test accuracy comes out to around 85% (as opposed to the LightGBM model that has a much lower test accuracy). Thus, this is our final model:
#
# RandomForestClassifier with hyperparameters:
#
# model__bootstrap = True
#
# model__criterion = gini
#
# model__max_depth = 10
#
# model__max_features = sqrt
#
# model__min_samples_leaf = 2
#
# model__min_samples_split = 5
#
# model__n_estimators = 200

# %% [markdown]
# ### Feature Importance

# %%
feature_importances = model_rfc_tuned.named_steps['model'].feature_importances_
plt.barh(X.columns, feature_importances[:8])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Random Forest Feature Importance')
plt.xticks(rotation=40)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the feature importance output, we can see that Loan Amount, Self Employment Status, Education Status, and the number of Dependants most significantly contribute to the chances at an applicant's Loan Status Approva!

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The datasets we acquired were from Kaggle, which is a publicly available data set for fair use. The privacy of individuals were kept and so privacy concerns do not apply to our project. The participants’ personal information including names, social security numbers, and emails were not included in the data sets. Furthermore, we noticed that some of the entries in the dataset contain no entries, suggesting that the participants have the freedom to decline to answer a particular question should they feel uncomfortable sharing that information to the public. For these reasons, we believe that the information presented in this dataset was obtained with consent of the participating individuals and that the datasets acquired were voluntary.
#
# In our data sets, there may be certain biases since there were definitely more males than females, more people who have less dependents, more educated people, and people who are not self-employed who got higher loan approval rates. This indicates that there may have been an unrealistic sampling of the population or the data collected was inaccurate. Furthermore, since the dataset does not include any information about the participants’ ethnicity, we have no idea if the data is biased towards a particular ethnic group or may have excluded certain minority group(s). Additionally, the dataset has no information regarding the location of each participant other than urban, rural, or semiurban, so we don’t know if the dataset is equally collected across America or if it’s biased towards particular states.
#
# We believe that there are most likely not many issues related to our topic area as Kaggle collects publicly available data. But if there were issues and other sampling biases we identify during our analysis, we would address them in our analysis as we present them in our project. For example, if we visualize our data and we notice that a certain group(s) have a significantly higher value than others for a particular feature, then we can focus only on that group and determine whether that particular group has a much higher sample size than the others or there is an outlier within that group. Another way we could resolve this issue during the analysis is to use resampling methods such as bootstrapping, or we could reorganize the data in a way that each group has roughly equal sample size.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this project, our research and analyses were focused on exploring the associations between different characteristics (Income, Education, Gender, Marriage Status, Dependents, Property Area) of a loan application and their loan approval status. We began by formulating the hypothesis that certain features such as income, education, gender, and marital status could significantly impact the likelihood of a loan being approved or rejected. Through rigorous analysis and exploration, we sought to identify the key determinants that contribute to the final decision in the loan approval process. We engineering an sklearn pipeline that was able to handle preprocessing, model compilation, feature selection, and hyperparameter tuning. The model that worked that best ended up being a RandomForestClassifier with select hyperparameters (they are listed above at the end of "Model Building" section). Our model achieved 85% macro accuracy!

# %% [markdown]
# ## Key Findings

# %% [markdown]
# ### Three Most Significant Features:

# %% [markdown]
# #### 1. Self-Employment

# %% [markdown]
# One of the standout revelations from our research is the substantial influence of an applicant's employment status, particularly whether they are self-employed. Utilizing a random forest classification approach, we determined that self-employment emerged as the single most crucial feature, with an impressive importance score of approximately 37%. This underscores the pivotal role self-employment plays in shaping loan approval outcomes and highlights it as a key determinant meticulously considered by lenders.

# %% [markdown]
# #### 2. Loan Amount Request:

# %% [markdown]
# The second most important feature identified by our random forest classifier is the loan amount requested by the applicant. With an importance score of about 21%, this finding underscores the significant role that the requested loan amount plays in the decision-making process. Despite being slightly less influential than self-employment, it remains notably more critical than other features considered, showcasing its substantial impact on the approval status.

# %% [markdown]
# #### 3. Number of Dependents:

# %% [markdown]
# Our analysis also revealed that the number of dependents an applicant has is a noteworthy factor influencing loan approval. While not as dominant as self-employment or loan amount, the number of dependents still demonstrated a considerable impact on the final decision.

# %% [markdown]
# ### Less Significant Features:

# %% [markdown]
# Several features, including Total Income, Property Area, Credit History, Loan Amount Term, and Education, were found to have less pronounced effects on loan approval status. Although these factors contribute to the overall decision-making process, their individual importance scores were comparatively lower than the three most influential features.

# %% [markdown]
# ## Model Performance and Future Directions:

# %% [markdown]
# Our chosen approach, employing a Random Forest Classification model, demonstrated robust performance in uncovering patterns within the data. The model's ability to accurately identify and prioritize influential features underscores its effectiveness in understanding the complex dynamics of loan approval. We were able to achieve 85% accuracy when predicting an applicant's loan approval status!
#
# Looking ahead, there are promising avenues for expanding upon this project. Firstly, acquiring a more extensive dataset with a larger sample size will enhance the reliability of our insights. Additionally, delving deeper into the nuanced interactions between features and considering more advanced modeling techniques may further refine our understanding of the factors influencing loan approval outcomes. As we continue to refine our models and explore additional variables, we anticipate gaining deeper insights that can contribute to more informed decision-making in the realm of loan approvals.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# - **Joseph Lee** — Abstract, Research Question, Ideas, Conclusion & Discussion, Video (Conclusion), Ethics and Privacy
# - **Kenneth Song** — Research Question, Ideas, Leadership, EDA descriptions, Ethics & Privacy, Conclusion & Discussion, Video (Research Question, Background)
# - **Georgio Feghali** — Research Question, Ideas, Hypothesis, Dataset selection, Conclusion & Discussion, Video (Data), Video recording
# - **Lorenzo Ramos** — Research Question, Ideas, Data Section, found Dataset, EDA descriptions, Conclusion & Discussion, Video (EDA)
# - **Sujay Talanki** — Research Question, Ideas, Background, EDA, Model Building, Conclusion & Discussion, Video (Model Building)
#
# We all worked together to complete each checkpoint.
